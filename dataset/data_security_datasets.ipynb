# %% [markdown]
# Libraries

# %%
import shutil
import pandas as pd
import os
import matplotlib.pyplot as plt
import re
import unicodedata
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("uciml/sms-spam-collection-dataset")

print("Path to dataset files:", path)

# %%
# Define source and destination paths
destination_path = "/content/drive/MyDrive/sms_spam_dataset"

# Move the dataset
# shutil.move(path, destination_path)

# %%
 os.listdir(destination_path)
# Out:
# ['spam.csv', '1']

# %% [markdown]
# ## understand the structure of the data

# %%
spam_1_df = pd.read_csv(destination_path + "/spam.csv", encoding='latin-1')

# %%
spam_1_df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
spam_1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
not_null_mask = spam_1_df['Unnamed: 2'].notnull()
not_null_rows = spam_1_df[not_null_mask]

# %%
not_null_rows
# Out:
#         v1                                                 v2  \
# 95    spam  Your free ringtone is waiting to be collected....
# 281    ham                                \Wen u miss someone
# 444    ham  \HEY HEY WERETHE MONKEESPEOPLE SAY WE MONKEYAR...
# 671   spam         SMS. ac sun0819 posts HELLO:\You seem cool
# 710    ham  Height of Confidence: All the Aeronautics prof...
# 899   spam  Your free ringtone is waiting to be collected....
# 1038   ham  Edison has rightly said, \A fool can ask more ...
# 1127   ham  Height of \Oh shit....!!\" situation: A guy th...
# 1266   ham    \Hey sorry I didntgive ya a a bellearlier hunny
# 1384   ham  Storming msg: Wen u lift d phne, u say \HELLO\...
# 1428   ham  Tell you what, if you make a little spreadshee...
# 1559   ham  Single line with a big meaning::::: \Miss anyt...
# 1637  spam  0A$NETWORKS allow companies to bill for SMS, s...
# 1669   ham  Very hurting n meaningful lines ever: \I compr...
# 1675   ham  Painful words- \I thought being Happy was the ...
# 1936   ham      My planning usually stops at \find hella weed
# 1937   ham  The fact that you're cleaning shows you know w...
# 1997   ham                    \YEH I AM DEF UP4 SOMETHING SAT
# 2087   ham                                      \alright babe
# 2170   ham  \CAN I PLEASE COME UP NOW IMIN TOWN.DONTMATTER...
# 2235   ham  \Si.como no?!listened2the plaid album-quite gd...
# 2255   ham      I just lov this line: \Hurt me with the truth
# 2406   ham  One of best dialogue in cute reltnship..!! \We...
# 2791   ham  Û_ we r stayin here an extra week, back next ...
# 2970   ham  Height of Confidence: All the Aeronautics prof...
# 3110   ham               Short But Cute : \ Be a good person
# 3145   ham               \SHIT BABE.. THASA BIT MESSED UP.YEH
# 3239   ham  A cute thought for friendship: \Its not necess...
# 3506   ham               Two fundamentals of cool life: \Walk
# 3525   ham  \HEY BABE! FAR 2 SPUN-OUT 2 SPK AT DA MO... DE...
# 3547   ham  Single line with a big meaning::::: \Miss anyt...
# 3640  spam  You can stop further club tones by replying \S...
# 3758   ham  GOD ASKED, \What is forgiveness?\" A little ch...
# 3788   ham              Are you sure you don't mean \get here
# 3793   ham                  Short But Cute: \Be a good person
# 3881   ham                  Short But Cute: \Be a good person
# 4130   ham  \Its Ur luck to Love someone. Its Ur fortune t...
# 4224   ham  \The world suffers a lot... Not because of the...
# 4454   ham  Storming msg: Wen u lift d phne, u say \HELLO\...
# 4455   ham  If you want to mapquest it or something look u...
# 4570   ham                 \CHA QUITEAMUZING THATåÕSCOOL BABE
# 4601   ham                     \Hey j! r u feeling any better
# 4668   ham  When I was born, GOD said, \Oh No! Another IDI...
# 4859   ham  \Response\" is one of d powerful weapon 2 occu...
# 4992   ham                                          \HEY KATE
# 5048   ham  Edison has rightly said, \A fool can ask more ...
# 5079   ham                      \Keep ur problems in ur heart
# 5081   ham  \HI BABE UAWAKE?FEELLIKW SHIT.JUSTFOUND OUT VI...
# 5264   ham  Storming msg: Wen u lift d phne, u say \HELLO\...
# 5268   ham                                                \ER
#
#                                              Unnamed: 2  \
# 95                                          PO Box 5249
# 281    the person is definitely special for u..... B...
# 444    HOWU DOIN? FOUNDURSELF A JOBYET SAUSAGE?LOVE ...
# 671    wanted to say hi. HI!!!\" Stop? Send STOP to ...
# 710     this wont even start........ Datz confidence.."
# 899                                         PO Box 5249
# 1038                                                 GN
# 1127                                           .;-):-D"
# 1266  just been in bedbut mite go 2 thepub l8tr if u...
# 1384   bt not his girlfrnd... G o o d n i g h t . . .@"
# 1428                                      I'll come up"
# 1559   don't miss ur best life for anything... Gud n...
# 1637   just as a shop has to give a guarantee on wha...
# 1669   But at d end my love compromised me for every...
# 1675   the toughest is acting Happy with all unspoke...
# 1936                                smoke hella weed\""
# 1937                     \" not \"what i need to do.\""
# 1997  JUST GOT PAYED2DAY & I HAVBEEN GIVEN Aå£50 PAY...
# 2087   justthought iåÕd sayhey! how u doin?nearly th...
# 2170  JUST REALLYNEED 2DOCD.PLEASE DONTPLEASE DONTIG...
# 2235                       u hav2hear it!c u sn xxxx\""
# 2255                                       I don't mind
# 2406   Dont Come Near My Body..!! Bcoz My Hands May ...
# 2791  Well there's still a bit left if you guys want...
# 2970    this wont even start........ Datz confidence.."
# 3110         but dont try to prove\" ..... Gud mrng..."
# 3145            SHE SHUDVETOLD U. DID URGRAN KNOW?NEWAY
# 3239         but watever u shared should be true\"...."
# 3506   like you are the KING\"...! OR \"Walk like yo...
# 3525                                   HAD A COOL NYTHO
# 3547   don't miss ur best life for anything... Gud n...
# 3640                        PO Box 1146 MK45 2WT (2/3)"
# 3758   \"It is d wonderful fruit that a tree gives w...
# 3788                   we made you hold all the weed\""
# 3793        but dont try to prove it..\" .Gud noon...."
# 3881        but dont try to prove it..\" .Gud noon...."
# 4130   its a miracle to Love a person who can't Love...
# 4224                                     Gud night...."
# 4454   bt not his girlfrnd... G o o d n i g h t . . .@"
# 4455   that's the tiny street where the parking lot is"
# 4570  PROBPOP IN & CU SATTHEN HUNNY 4BREKKIE! LOVE J...
# 4601   hopeSo hunny. i amnow feelin ill & ithink i m...
# 4668                                           GOD said
# 4859   always give response 2 who cares 4 U\"... Gud...
# 4992   HOPE UR OK... WILL GIVE U A BUZ WEDLUNCH. GO ...
# 5048                                                 GN
# 5079   b'coz nobody will fight for u. Only u &amp; u...
# 5081                                DEVIOUSBITCH.ANYWAY
# 5264   bt not his girlfrnd... G o o d n i g h t . . .@"
# 5268   ENJOYIN INDIANS AT THE MO..yeP. SaLL gOoD Heh...
#
#                                       Unnamed: 3  \
# 95                          MK17 92H. 450Ppw 16"
# 281                             why to miss them
# 444                                          NaN
# 671                                          NaN
# 710                                          NaN
# 899                         MK17 92H. 450Ppw 16"
# 1038                                          GE
# 1127                                         NaN
# 1266                                         NaN
# 1384                                         NaN
# 1428                                         NaN
# 1559                                         NaN
# 1637                                         NaN
# 1669                                         NaN
# 1675                                         NaN
# 1936                                         NaN
# 1937                                         NaN
# 1997                                         NaN
# 2087                                         NaN
# 2170    U NO THECD ISV.IMPORTANT TOME 4 2MORO\""
# 2235                                         NaN
# 2255    i wil tolerat.bcs ur my someone..... But
# 2406                                         NaN
# 2791                                         NaN
# 2970                                         NaN
# 3110                                         NaN
# 3145   ILLSPEAK 2 U2MORO WEN IM NOT ASLEEP...\""
# 3239                                         NaN
# 3506          whoever is the KING\"!... Gud nyt"
# 3525                              TX 4 FONIN HON
# 3547                                         NaN
# 3640                                         NaN
# 3758                                         NaN
# 3788                                         NaN
# 3793                                         NaN
# 3881                                         NaN
# 4130                                         NaN
# 4224                                         NaN
# 4454                                         NaN
# 4455                                         NaN
# 4570                                         NaN
# 4601                                         NaN
# 4668            \"OH No! COMPETITION\". Who knew
# 4859                                         NaN
# 4992                                         NaN
# 5048                                          GE
# 5079                                         NaN
# 5081                              IåÕL CALL U\""
# 5264                                         NaN
# 5268                                         NaN
#
#                                              Unnamed: 4
# 95                                                  NaN
# 281                       just Keep-in-touch\" gdeve.."
# 444                                                 NaN
# 671                                                 NaN
# 710                                                 NaN
# 899                                                 NaN
# 1038                                            GNT:-)"
# 1127                                                NaN
# 1266                                                NaN
# 1384                                                NaN
# 1428                                                NaN
# 1559                                                NaN
# 1637                                                NaN
# 1669                                                NaN
# 1675                                                NaN
# 1936                                                NaN
# 1937                                                NaN
# 1997                                                NaN
# 2087                                                NaN
# 2170                                                NaN
# 2235                                                NaN
# 2255   Never comfort me with a lie\" gud ni8 and swe...
# 2406                                                NaN
# 2791                                                NaN
# 2970                                                NaN
# 3110                                                NaN
# 3145                                                NaN
# 3239                                                NaN
# 3506                                                NaN
# 3525                CALL 2MWEN IM BK FRMCLOUD 9! J X\""
# 3547                                                NaN
# 3640                                                NaN
# 3758                                                NaN
# 3788                                                NaN
# 3793                                                NaN
# 3881                                                NaN
# 4130                                                NaN
# 4224                                                NaN
# 4454                                                NaN
# 4455                                                NaN
# 4570                                                NaN
# 4601                                                NaN
# 4668    one day these two will become FREINDS FOREVER!"
# 4859                                                NaN
# 4992                                                NaN
# 5048                                            GNT:-)"
# 5079                                                NaN
# 5081                                                NaN
# 5264                                                NaN
# 5268                                                NaN

# %%
pd.set_option('display.max_colwidth', 200)
not_null_rows['Unnamed: 2'].head()
# Out:
# 95                                                                      PO Box 5249
# 281     the person is definitely special for u..... But if the person is so special
# 444                         HOWU DOIN? FOUNDURSELF A JOBYET SAUSAGE?LOVE JEN XXX\""
# 671                             wanted to say hi. HI!!!\" Stop? Send STOP to 62468"
# 710                                 this wont even start........ Datz confidence.."
# Name: Unnamed: 2, dtype: object

# %% [markdown]
# I noticed that Unnamed: 2 ,	Unnamed: 3 ,	Unnamed: 4 columns contain a lot of missing values
#
# and mainly the length of sentence of non-null rows in these columns are relatively small
#
# so we can ignore it since filling methods will require more knowledge about the columns than the one we actually have

# %%
new_df = spam_1_df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)

# %%
new_df.head()
# Out:
#      v1  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                             v2
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though

# %% [markdown]
# rename columns and reorder them

# %%
new_df = new_df.rename(columns={"v1": "target", "v2": "email"})
new_df = new_df.iloc[:, [1,0]]
new_df.head()
# Out:
#                                                                                                                                                          email  \
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though
#
#   target
# 0    ham
# 1    ham
# 2   spam
# 3    ham
# 4    ham

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   5572 non-null   object
#  1   target  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
new_df.isna().sum()
# Out:
# email     0
# target    0
# dtype: int64

# %%
print(new_df.duplicated().sum())
# Out:
# 403

# %% [markdown]
# I noticed that there is repetition, let's take a closer look at the duplicated rows

# %%
new_df[new_df.duplicated()].head()
# Out:
#                                                                                                                                                                 email  \
# 102  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# 153  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# 206      As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.
# 222                                                                                                                                            Sorry, I'll call later
# 325                                                                                                                                  No calls..messages..missed calls
#
#     target
# 102    ham
# 153    ham
# 206    ham
# 222    ham
# 325    ham

# %% [markdown]
# The best practice is to drop duplicated rows and to do so I will use **drop_duplicates** that basically keep the first row of the duplicated rows and drop the rest

# %%
new_df.drop_duplicates()
# Out:
#                                                                                                                                                                   email  \
# 0                                                       Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                         Ok lar... Joking wif u oni...
# 2           Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                                     U dun say so early hor... U c already then say...
# 4                                                                                                         Nah I don't think he goes to usf, he lives around here though
# ...                                                                                                                                                                 ...
# 5567  This is the 2nd time we have tried 2 contact u. U have won the å£750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.
# 5568                                                                                                                              Will Ì_ b going to esplanade fr home?
# 5569                                                                                                          Pity, * was in mood for that. So...any other suggestions?
# 5570                                      The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free
# 5571                                                                                                                                         Rofl. Its true to its name
#
#      target
# 0       ham
# 1       ham
# 2      spam
# 3       ham
# 4       ham
# ...     ...
# 5567   spam
# 5568    ham
# 5569    ham
# 5570    ham
# 5571    ham
#
# [5169 rows x 2 columns]

# %% [markdown]
# ## cleaned data from null and duplicates

# %% [markdown]
# Now the data is a little bit cleaner where:
#
# 1) the data has no null values
#
# 2) the data has no duplicated emails

# %% [markdown]
# ## Check for the class balance

# %%
# new_df['target'].value_counts()
plt.bar(new_df['target'].unique() ,new_df['target'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# although there is a class imbalance but it comes from reality where we notice in real world that the number of spams is less than regular emails
#
# solutions:
# as we suggested in the draft
#
# we will work on Lexical & Content-Based Evasion Experiment
#
# - where we will try to generate spam messages
# - it will help increasing the dataset diversity thus fix the class imbalance
# - it will also improve the model accuracy

# %%
new_df.iloc[2][0]
# Out:
# <ipython-input-23-60e2ad5faafd>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_df.iloc[2][0]
# "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"

# %% [markdown]
# I noticed that the text needs some processing where there is the following to consider:
#
# 1) there is some meangingless numbers
#
# 2) the same words are written in different letter cases
#
# 3) there are punctuations

# %% [markdown]
# ## prepcrossing data

# %% [markdown]
# But since this dataset is going to be shared for between all of the models:
# - Logistic regression model
# - LSTM model
# - Bert model
#
# The preprocessing approach that I will follow is going to be general since for example:
#
# - in LSTM, we will need word embedding technique which required data to be stemmed
# - in Bert fine tuning, the data needs to be as natural as possible

# %% [markdown]
# Precprocessing steps I followed:
#
# 1) Standardizing Whitespaces (removes extra spaces, tabs, and newlines)
#
# 2) Remove HTML Tags & URLs
#
# 3) Remove Non-ASCII Characters (e.g., emojis, foreign symbols)

# %%
import re
import string
import unicodedata

def clean_text(text):
    if not isinstance(text, str):  # Ensure input is a string
        return ""

    # 1. Standardizing Whitespaces (removes extra spaces, tabs, and newlines)
    text = re.sub(r'\s+', ' ', text).strip()

    # 2. Remove HTML Tags & URLs
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+|www\S+', '', text)  # Remove URLs

    # 3. Remove Non-ASCII Characters (e.g., emojis, foreign symbols)
    text = ''.join(char for char in text if unicodedata.category(char)[0] != 'C' and ord(char) < 128)

    return text

# %%
# Example Usage
data_example = pd.DataFrame({'email': [
    "Hello!  Visit <a href='https://example.com'>this link</a> now! 😊",
    "Check this out: www.example.com     New updates available!",
    "    This    has  extra spaces     and tabs.    "
]})


data_example['cleaned_email'] = data_example['email'].apply(clean_text)
data_example
# Out:
#                                                               email  \
# 0  Hello!  Visit <a href='https://example.com'>this link</a> now! 😊
# 1        Check this out: www.example.com     New updates available!
# 2                       This    has  extra spaces     and tabs.
#
#                              cleaned_email
# 0             Hello! Visit this link now!
# 1  Check this out:  New updates available!
# 2          This has extra spaces and tabs.

# %%
new_df['email'] = new_df['email'].apply(clean_text)

# %% [markdown]
# ## Splitting the dataset

# %% [markdown]
# 1) I ensure that the results are reproducible by setting `random_state=42` parameter
#
# 2) I ensure an even class distribution across splits by setting `stratify=new_df['target']` parameter

# %%
# First, split into train (80%) and test (20%)
train_data, test_data = train_test_split(new_df, test_size=0.2, random_state=42, stratify=new_df['target'])

# Then, split the train set further into train (80%) and validation (20%)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42, stratify=train_data['target'])

# Save the datasets
train_data.to_csv("train.csv", index=False)
val_data.to_csv("val.csv", index=False)
test_data.to_csv("test.csv", index=False)

print(f"Train size: {len(train_data)}, Validation size: {len(val_data)}, Test size: {len(test_data)}")
# Out:
# Train size: 3565, Validation size: 892, Test size: 1115

# %%
print('train dataset: \n',train_data['target'].value_counts())
print('val dataset: \n',val_data['target'].value_counts())
print('test dataset: \n',test_data['target'].value_counts())
# Out:
# train dataset:
#  target
# ham     3087
# spam     478
# Name: count, dtype: int64
# val dataset:
#  target
# ham     772
# spam    120
# Name: count, dtype: int64
# test dataset:
#  target
# ham     966
# spam    149
# Name: count, dtype: int64

# %% [markdown]
# ## Enron-Spam dataset

# %% [markdown]
#   Taking a look at the second dataset structure

# %%
import kagglehub

# Download latest version
path_2 = kagglehub.dataset_download("wanderfj/enron-spam")

print("Path to dataset files:", path_2)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/wanderfj/enron-spam?dataset_version_number=1...
# 100%|██████████| 28.8M/28.8M [00:00<00:00, 64.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/wanderfj/enron-spam/versions/1

# %%
# Define source and destination paths
destination_path_2 = "/content/drive/MyDrive/enron-spam_dataset"

# Move the dataset
shutil.move(path, destination_path_2)
# Out:
# '/content/drive/MyDrive/enron-spam_dataset/1'

# %%
os.listdir(path_2 + '/enron1/spam')[:10]
# Out:
# ['0102.2003-12-28.GP.spam.txt',
#  '2526.2004-10-17.GP.spam.txt',
#  '3419.2005-01-09.GP.spam.txt',
#  '4924.2005-07-26.GP.spam.txt',
#  '0840.2004-04-13.GP.spam.txt',
#  '2179.2004-09-15.GP.spam.txt',
#  '2555.2004-10-20.GP.spam.txt',
#  '2716.2004-11-03.GP.spam.txt',
#  '0512.2004-02-20.GP.spam.txt',
#  '2491.2004-10-13.GP.spam.txt']

# %%
# check the number of datasets included and what are they
print("the number of datasets included is: ",len(os.listdir(path_2)), "\n")
print("the datasets included are: ",os.listdir(path_2), "\n")

#explore dataset 1
print("explore dataset enron1","\n")
print("the files included are: ",os.listdir(path_2 + '/enron1'), "\n")

# check the number of spam samples
print("the number of spam samples : ",len(os.listdir(path_2 + '/enron1/spam')),"\n")

# check the ham number of samples
print("the number of ham samples: ",len(os.listdir(path_2 + '/enron1/ham')),"\n")

# check an example of one of the spam emails
print("example of spam email (2092.2004-09-08.GP.spam.txt) : ","\n")
f = open("/root/.cache/kagglehub/datasets/wanderfj/enron-spam/versions/1/enron1/spam/2092.2004-09-08.GP.spam.txt", "r")
print(f.read())

# check the summary file
print("the summary file of enron1 : ","\n")
f = open("/root/.cache/kagglehub/datasets/wanderfj/enron-spam/versions/1/enron1/Summary.txt", "r")
print(f.read())
# Out:
# the number of datasets included is:  6
#
# the datasets included are:  ['enron5', 'enron3', 'enron1', 'enron6', 'enron2', 'enron4']
#
# explore dataset enron1
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  1500
#
# the number of ham samples:  3672
#
# example of spam email (2092.2004-09-08.GP.spam.txt) :
#
# Subject: cialis , valium , viagra , xanax at low price ! no prescription needed !
# discount rx is simple , quick , and affordable ! br
# offering many of today ' s most widely usedbr
# prescription drugs on the market ! brbr
# zoloft , xanax , ambien , paxil , valium , viagra and many more !
# br
# just click below for these special savings !
# a href = http : / / www . grand 2 packz . com / index . php ? id = 188 click here now !
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: farmer-d
# - Total number: 3672 emails
# - Date of first email: 1999-12-10
# - Date of last email: 2002-01-11
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: GP
# - Total number: 1500 emails
# - Date of first email: 2003-12-18
# - Date of last email: 2005-09-06
# - Similars deletion: No
# - Encoding: No
#
# Spam:Legitimate rate = 1:3
# Total number of emails (legitimate + spam): 5975

# %% [markdown]
# create a dataframe of two columns (text, label) from the folders structure

# %%
def create_df_from_enron(main_folder):
    data = []

    for label in ['spam', 'ham']:
        folder_path = os.path.join(main_folder, label)
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
                content = file.read()
                data.append([content, label])

    df = pd.DataFrame(data, columns=['email', 'target'])

    df = shuffle(df, random_state=42).reset_index(drop=True)

    return df

# %%
main_folder = path_2 + '/enron1'
enron1_df = create_df_from_enron(main_folder)
enron1_df.head()
# Out:
#                                                                                                                                                                                                      email  \
# 0                   Subject: ponderosa pine energy plant - start - up\nfyi >\nthe ponderosa pine energy plant is forecasted to start - up on friday , september 28 , 2001 at approximately 6 : 00 am .\nmm
# 1  Subject: unify performance problem on wednesday\nfyi .\n- - - - - - - - - - - - - - - - - - - - - - forwarded by brenda f herod / hou / ect on 05 / 05 / 2000\n09 : 01 am - - - - - - - - - - - - - ...
# 2  Subject: time is right to invest in the euro - 677955\nz 629 um 45\nlondon - - ( ap worldstream via comtex ) - - the u . s . dollar has fallen to an all - time low against the euro . the euro hit ...
# 3                                                                                    Subject: enron / hpl nom . s for wednesday , aug . 6 , 2000\n( see attached file : hplo 906 . xls )\n- hplo 906 . xls
# 4  Subject: re : october wellhead\nvance ,\ndeal # 420022 has been created and entered in sitara .\nbob\nvance l taylor\n09 / 28 / 2000 02 : 09 pm\nto : julie meyers / hou / ect @ ect\ncc : daren j f...
#
#   target
# 0    ham
# 1    ham
# 2   spam
# 3    ham
# 4    ham

# %% [markdown]
# check for null and duplicated

# %%
print(enron1_df.duplicated().sum())
# Out:
# 178

# %%
print(enron1_df.isna().sum())
# Out:
# email     0
# target    0
# dtype: int64

# %% [markdown]
# so the data contain about 178 duplicated values, so I will drop them

# %%
enron1_df.drop_duplicates(inplace=True)

# %%
enron1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4994 entries, 0 to 5171
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   4994 non-null   object
#  1   target  4994 non-null   object
# dtypes: object(2)
# memory usage: 117.0+ KB

# %%
enron1_df.iloc[1,0]
# Out:
# 'Subject: unify performance problem on wednesday\nfyi .\n- - - - - - - - - - - - - - - - - - - - - - forwarded by brenda f herod / hou / ect on 05 / 05 / 2000\n09 : 01 am - - - - - - - - - - - - - - - - - - - - - - - - - - -\nrita wynne\n05 / 05 / 2000 08 : 11 am\nto : brenda f herod / hou / ect @ ect\ncc :\nsubject : unify performance problem on wednesday\nfyi . . . . . . . . .\n- - - - - - - - - - - - - - - - - - - - - - forwarded by rita wynne / hou / ect on 05 / 05 / 2000 08 : 10 am\n- - - - - - - - - - - - - - - - - - - - - - - - - - -\nfrom : dave nommensen 05 / 04 / 2000 06 : 56 pm\nto : george smith / hou / ect @ ect , edward terry / hou / ect @ ect , tricia\nbowen / hou / ect @ ect , randall l gay / hou / ect @ ect , patti sullivan / hou / ect @ ect , pat\nclynes / corp / enron @ enron , carlos j rodriguez / hou / ect @ ect , robert\nsuperty / hou / ect @ ect , bryce baxter / hou / ect @ ect , rita wynne / hou / ect @ ect , donna\ngreif / hou / ect @ ect\ncc : jeff johnson / corp / enron @ enron , tommy j yanowski / hou / ect @ ect , beth\nperlman / hou / ect @ ect , scott williamson / hou / ect @ ect , jim ogg / hou / ect @ ect , regan\nm smith / hou / ect @ ect , kenneth m harmon / hou / ect @ ect\nsubject : unify performance problem on wednesday\nas you are aware , the unify system experienced significant performance\nproblems wednesday from approx 9 : 30 am - 11 : 20 am . the duration of the\nproblem was due to a type of system behavior we had not experienced before .\nthe problem was exacerbated by a multitude of additional user logins thinking\nthat a fresh login might work better . additional logins never improve\nperformance and generally degrade it , but that is another story . ( there was\nactually a single user with 21 sessions ! ) we had to " bounce " the server\ntwice to bring the system back to its normal level of performance .\nthe good news is that we found out what caused the problem . it was not a\nparticular user or a particular report or process . it was actually an\nintentional change to a specific table that we have done numerous times in\nthe past , but this particular change had drastic side effects . we have\ncontacted sybase with this problem to see if they can help determine if the\nbehavior is a " feature " or a bug . in the meanwhile , we will do these types\nof changes at night during scheduled outages .\ni apologize for the frustration , anxiety , and extra work brought on by this\nproblem and will take every precaution to see that it does not happen again .\nif you have any further questions or comments , please feel free to give me a\ncall .\ndave n .'

# %% [markdown]
# preprcoess the email column
#
# I will apply the exact same function I applied on the previous dataset

# %%
enron1_df['email'] = enron1_df['email'].apply(clean_text)

# %%
enron1_df.iloc[1,0]
# Out:
# 'Subject: unify performance problem on wednesday fyi . - - - - - - - - - - - - - - - - - - - - - - forwarded by brenda f herod / hou / ect on 05 / 05 / 2000 09 : 01 am - - - - - - - - - - - - - - - - - - - - - - - - - - - rita wynne 05 / 05 / 2000 08 : 11 am to : brenda f herod / hou / ect @ ect cc : subject : unify performance problem on wednesday fyi . . . . . . . . . - - - - - - - - - - - - - - - - - - - - - - forwarded by rita wynne / hou / ect on 05 / 05 / 2000 08 : 10 am - - - - - - - - - - - - - - - - - - - - - - - - - - - from : dave nommensen 05 / 04 / 2000 06 : 56 pm to : george smith / hou / ect @ ect , edward terry / hou / ect @ ect , tricia bowen / hou / ect @ ect , randall l gay / hou / ect @ ect , patti sullivan / hou / ect @ ect , pat clynes / corp / enron @ enron , carlos j rodriguez / hou / ect @ ect , robert superty / hou / ect @ ect , bryce baxter / hou / ect @ ect , rita wynne / hou / ect @ ect , donna greif / hou / ect @ ect cc : jeff johnson / corp / enron @ enron , tommy j yanowski / hou / ect @ ect , beth perlman / hou / ect @ ect , scott williamson / hou / ect @ ect , jim ogg / hou / ect @ ect , regan m smith / hou / ect @ ect , kenneth m harmon / hou / ect @ ect subject : unify performance problem on wednesday as you are aware , the unify system experienced significant performance problems wednesday from approx 9 : 30 am - 11 : 20 am . the duration of the problem was due to a type of system behavior we had not experienced before . the problem was exacerbated by a multitude of additional user logins thinking that a fresh login might work better . additional logins never improve performance and generally degrade it , but that is another story . ( there was actually a single user with 21 sessions ! ) we had to " bounce " the server twice to bring the system back to its normal level of performance . the good news is that we found out what caused the problem . it was not a particular user or a particular report or process . it was actually an intentional change to a specific table that we have done numerous times in the past , but this particular change had drastic side effects . we have contacted sybase with this problem to see if they can help determine if the behavior is a " feature " or a bug . in the meanwhile , we will do these types of changes at night during scheduled outages . i apologize for the frustration , anxiety , and extra work brought on by this problem and will take every precaution to see that it does not happen again . if you have any further questions or comments , please feel free to give me a call . dave n .'

# %% [markdown]
# ## Splitting datasets

# %%
# First, split into train (80%) and test (20%)
train_data, test_data = train_test_split(enron1_df, test_size=0.2, random_state=42, stratify=enron1_df['target'])

# Then, split the train set further into train (80%) and validation (20%)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42, stratify=train_data['target'])

# Save the datasets
train_data.to_csv("enron1_train.csv", index=False)
val_data.to_csv("enron1_val.csv", index=False)
test_data.to_csv("enron1_test.csv", index=False)

print(f"Train size: {len(train_data)}, Validation size: {len(val_data)}, Test size: {len(test_data)}")

print('train dataset: \n',train_data['target'].value_counts())
print('val dataset: \n',val_data['target'].value_counts())
print('test dataset: \n',test_data['target'].value_counts())
# Out:
# Train size: 3196, Validation size: 799, Test size: 999
# train dataset:
#  target
# ham     2260
# spam     936
# Name: count, dtype: int64
# val dataset:
#  target
# ham     565
# spam    234
# Name: count, dtype: int64
# test dataset:
#  target
# ham     706
# spam    293
# Name: count, dtype: int64

# %% [markdown]
# ## explore with another enron dataset

# %%
datasets = os.listdir(path_2)
for name in datasets:
  dataset_name = '/' + name
  #explore dataset 1
  print("explore dataset "+ dataset_name,"\n")
  print("the files included are: ",os.listdir(path_2 + dataset_name), "\n")

  # check the number of spam samples
  print("the number of spam samples : ",len(os.listdir(path_2 + dataset_name + '/spam')),"\n")

  # check the ham number of samples
  print("the number of ham samples: ",len(os.listdir(path_2 + dataset_name + '/ham')),"\n")

  # check the summary file
  print("the summary file of enron1 : ","\n")
  f = open("/root/.cache/kagglehub/datasets/wanderfj/enron-spam/versions/1" +dataset_name +"/Summary.txt", "r")
  print(f.read())
# Out:
# explore dataset /enron5
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  3675
#
# the number of ham samples:  1500
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: beck-s
# - Total number: 1500 emails
# - Date of first email: 2000-01-17
# - Date of last email: 2001-05-24
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: SpamAssassin + HoneyPot
# - Total number: 3675 emails
# - Date of first email: 2001-05-25
# - Date of last email: 2005-07-22
# - Similars deletion: Yes
# - Encoding: No
#
# Spam:Legitimate rate = 3:1
# Total number of emails (legitimate + spam): 5175
# explore dataset /enron3
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  1500
#
# the number of ham samples:  4012
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: kitchen-l
# - Total number: 4012 emails
# - Date of first email: 2001-02-07
# - Date of last email: 2002-02-06
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: BG
# - Total number: 1500 emails
# - Date of first email: 2004-08-01
# - Date of last email: 2005-07-31
# - Similars deletion: Yes
# - Encoding: No
#
# Spam:Legitimate rate = 1:3
# Total number of emails (legitimate + spam): 5512
# explore dataset /enron1
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  1500
#
# the number of ham samples:  3672
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: farmer-d
# - Total number: 3672 emails
# - Date of first email: 1999-12-10
# - Date of last email: 2002-01-11
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: GP
# - Total number: 1500 emails
# - Date of first email: 2003-12-18
# - Date of last email: 2005-09-06
# - Similars deletion: No
# - Encoding: No
#
# Spam:Legitimate rate = 1:3
# Total number of emails (legitimate + spam): 5975
#
# explore dataset /enron6
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  4500
#
# the number of ham samples:  1500
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: lokay-m
# - Total number: 1500 emails
# - Date of first email: 2000-06-06
# - Date of last email: 2002-03-25
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: BG
# - Total number: 4500 emails
# - Date of first email: 2004-08-01
# - Date of last email: 2005-07-31
# - Similars deletion: Yes
# - Encoding: No
#
# Spam:Legitimate rate = 3:1
# Total number of emails (legitimate + spam): 6000
# explore dataset /enron2
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  1496
#
# the number of ham samples:  4361
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: kaminski-v
# - Total number: 4361 emails
# - Date of first email: 1999-12-10
# - Date of last email: 2001-05-22
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: SpamAssassin + HoneyPot
# - Total number: 1496 emails
# - Date of first email: 2001-05-25
# - Date of last email: 2005-07-22
# - Similars deletion: Yes
# - Encoding: No
#
# Spam:Legitimate rate = 1:3
# Total number of emails (legitimate + spam): 5857
#
# explore dataset /enron4
#
# the files included are:  ['ham', 'Summary.txt', 'spam']
#
# the number of spam samples :  4499
#
# the number of ham samples:  1500
#
# the summary file of enron1 :
#
# Legitimate
# ----------
# - Owner: williams-w3
# - Total number: 1500 emails
# - Date of first email: 2001-04-02
# - Date of last email: 2002-02-07
# - Similars deletion: No
# - Encoding: No
#
#
# Spam
# ----
# - Owner: GP
# - Total number: 4500 emails
# - Date of first email: 2003-12-18
# - Date of last email: 2005-09-06
# - Similars deletion: No
# - Encoding: No
#
# Spam:Legitimate rate = 3:1
# Total number of emails (legitimate + spam): 6000

# %% [markdown]
# I noticed that all of the remaining datasets collected and published between 2002 and 2005 which makes all of them probably contain a similar spam envasion methods
#
# I will select then the dataset that contains a higher number of data samples which is enron2

# %%
main_folder = path_2 + '/enron2'
enron2_df = create_df_from_enron(main_folder)
enron2_df.head()
# Out:
#                                                                                                                                                                                                      email  \
# 0  Subject: from robert schenck , henwood\nsandeep ,\ni don ' t know if robert sent you this directly , so am forwarding a copy .\n- - stinson\n- - - - - - - - - - - - - - - - - - - - - - forwarded b...
# 1  Subject: interview with the enron research group\ngood morning frank :\nvince kaminski and the enron research group would like to bring you to\nhouston for an interview , sometime around the last ...
# 2  Subject: resume and available dates for amy ward\nvince : here is an electronic version of amy ward ' s resume .\n- - stinson\n- - - - - - - - - - - - - - - - - - - - - - forwarded by stinson gibn...
# 3  Subject: select small - cap for astute investors\nmomentum alert issued for july 18 , 2005\nexplosive pick for our members\n! ! ! ride the stairway to heaven ! ! ! !\ngood day to all broker ' s , ...
# 4  Subject: contact info . during my vacation\ncell : 011 - 91 - 984 - 9022360 ( try this first )\nhyderabad : 011 - 91 - 40 - 7114833\nvijayawada : 011 - 91 - 866 - 430928 ( dec 28 - jan 8 )\nbombay...
#
#   target
# 0    ham
# 1    ham
# 2    ham
# 3   spam
# 4    ham

# %% [markdown]
# check for null values and duplicates

# %%
print("number of duplicates: ",enron2_df.duplicated().sum())
print(enron2_df.isna().sum())
# Out:
# number of duplicates:  33
# email     0
# target    0
# dtype: int64

# %% [markdown]
# I noticed that the data contains 33 duplicated entries so I will drop them

# %%
enron2_df.drop_duplicates(inplace=True)

# %%
enron2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5824 entries, 0 to 5856
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   5824 non-null   object
#  1   target  5824 non-null   object
# dtypes: object(2)
# memory usage: 136.5+ KB

# %%
enron2_df['email'] = enron2_df['email'].apply(clean_text)

# %% [markdown]
# splitting datasets

# %%
# First, split into train (80%) and test (20%)
train_data, test_data = train_test_split(enron2_df, test_size=0.2, random_state=42, stratify=enron2_df['target'])

# Then, split the train set further into train (80%) and validation (20%)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42, stratify=train_data['target'])

# Save the datasets
train_data.to_csv("enron2_train.csv", index=False)
val_data.to_csv("enron2_val.csv", index=False)
test_data.to_csv("enron2_test.csv", index=False)

print(f"Train size: {len(train_data)}, Validation size: {len(val_data)}, Test size: {len(test_data)}")

print('train dataset: \n',train_data['target'].value_counts())
print('val dataset: \n',val_data['target'].value_counts())
print('test dataset: \n',test_data['target'].value_counts())
# Out:
# Train size: 3727, Validation size: 932, Test size: 1165
# train dataset:
#  target
# ham     2769
# spam     958
# Name: count, dtype: int64
# val dataset:
#  target
# ham     693
# spam    239
# Name: count, dtype: int64
# test dataset:
#  target
# ham     866
# spam    299
# Name: count, dtype: int64
